# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# %cd "//content/drive/MyDrive/Colab Notebooks/Universidad/Progra 2/Proyecto/"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Universidad/Progra 2/Proyecto

# %%
df = pd.read_excel("Global_Mobile_Prices_2025_Limpia1.xlsx")
df.head(10)
# Out:
#      brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 0     Oppo                A98 111        855      16         128        108
# 1   Realme            11 Pro+ 843        618       6         128         64
# 2   Xiaomi  Redmi Note 14 Pro 461        258      16          64         64
# 3     Vivo               V29e 744        837       6         512         48
# 4    Apple  iPhone 16 Pro Max 927        335      12         128        200
# 5  OnePlus             Nord 4 295        938      16         512        200
# 6  Infinix          GT 20 Pro 112        418      12         256         64
# 7    Apple  iPhone 16 Pro Max 232       1447      16          64         64
# 8  Infinix             Hot 40 111       1354       6        1024         12
# 9   Realme           GT 7 Pro 668        311       8        1024         50
#
#    battery_mah  display_size_inch  charging_watt 5g_support       os  \
# 0         6000                6.6             33        Yes  Android
# 1         4500                6.9            100        Yes  Android
# 2         4000                6.8             44        Yes  Android
# 3         4500                6.0             65        Yes  Android
# 4         5000                6.9            100        Yes      iOS
# 5         5000                6.2            120         No  Android
# 6         6000                6.9             44         No  Android
# 7         4500                6.7             33        Yes      iOS
# 8         5500                5.7             18        Yes  Android
# 9         5500                6.9             44        Yes  Android
#
#             processor  rating release_month  year
# 0           Helio G99     3.8      February  2025
# 1           Tensor G4     4.4        August  2025
# 2             A18 Pro     4.1         March  2025
# 3         Exynos 2400     4.1        August  2025
# 4      Dimensity 9300     3.5      February  2025
# 5         Exynos 2400     3.7           May  2025
# 6         Exynos 2400     4.1         April  2025
# 7         Exynos 2400     4.7      November  2025
# 8           Tensor G4     4.0          July  2025
# 9  Snapdragon 6 Gen 1     4.4         March  2025

# %% [markdown]
# # Informacion del dataframe

# %%
#tamaño del dataframe
df.shape
# Out:
# (1000, 18)

# %%
# Informacion del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              1000 non-null   object
#  1   model              1000 non-null   object
#  2   price_usd          1000 non-null   int64
#  3   ram_gb             1000 non-null   int64
#  4   storage_gb         1000 non-null   int64
#  5   camera_mp          1000 non-null   int64
#  6   battery_mah        1000 non-null   int64
#  7   display_size_inch  1000 non-null   float64
#  8   charging_watt      1000 non-null   int64
#  9   5g_support         1000 non-null   object
#  10  os                 1000 non-null   object
#  11  processor          1000 non-null   object
#  12  rating             1000 non-null   float64
#  13  release_month      1000 non-null   object
#  14  year               1000 non-null   int64
# dtypes: float64(2), int64(7), object(6)
# memory usage: 117.3+ KB

# %%
#descripción estadística
print(df['rating'].describe())
print(df['price_usd'].describe())
print(df['charging_watt'].describe())
# Out:
# count    1000.000000
# mean        4.229900
# std         0.439965
# min         3.500000
# 25%         3.800000
# 50%         4.200000
# 75%         4.600000
# max         5.000000
# Name: rating, dtype: float64
# count    1000.000000
# mean      813.478000
# std       411.708367
# min       101.000000
# 25%       449.250000
# 50%       822.000000
# 75%      1166.250000
# max      1499.000000
# Name: price_usd, dtype: float64
# count    1000.000000
# mean       63.791000
# std        36.333751
# min        18.000000
# 25%        33.000000
# 50%        65.000000
# 75%       100.000000
# max       120.000000
# Name: charging_watt, dtype: float64

# %% [markdown]
# #Limpieza de datos

# %%
#suma de los datos faltantes
df.isnull().sum()
# Out:
# brand                0
# model                0
# price_usd            0
# ram_gb               0
# storage_gb           0
# camera_mp            0
# battery_mah          0
# display_size_inch    0
# charging_watt        0
# 5g_support           0
# os                   0
# processor            0
# rating               0
# release_month        0
# year                 0
# dtype: int64

# %%
#porcentaje de los datos faltantes
(df.isnull().sum() / len(df)) * 100
# Out:
# brand                0.0
# model                0.0
# price_usd            0.0
# ram_gb               0.0
# storage_gb           0.0
# camera_mp            0.0
# battery_mah          0.0
# display_size_inch    0.0
# charging_watt        0.0
# 5g_support           0.0
# os                   0.0
# processor            0.0
# rating               0.0
# release_month        0.0
# year                 0.0
# dtype: float64

# %%
#Borrar la columna year
df = df.drop(columns=["year"])
df.head()
# Out:
#     brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 0    Oppo                A98 111        855      16         128        108
# 1  Realme            11 Pro+ 843        618       6         128         64
# 2  Xiaomi  Redmi Note 14 Pro 461        258      16          64         64
# 3    Vivo               V29e 744        837       6         512         48
# 4   Apple  iPhone 16 Pro Max 927        335      12         128        200
#
#    battery_mah  display_size_inch  charging_watt 5g_support       os  \
# 0         6000                6.6             33        Yes  Android
# 1         4500                6.9            100        Yes  Android
# 2         4000                6.8             44        Yes  Android
# 3         4500                6.0             65        Yes  Android
# 4         5000                6.9            100        Yes      iOS
#
#         processor  rating release_month
# 0       Helio G99     3.8      February
# 1       Tensor G4     4.4        August
# 2         A18 Pro     4.1         March
# 3     Exynos 2400     4.1        August
# 4  Dimensity 9300     3.5      February

# %%
sns.heatmap(df.isnull(), cbar=False)
plt.title("Mapa de valores faltantes")
plt.show()

# %%
df.head()
# Out:
#     brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 0    Oppo                A98 111        855      16         128        108
# 1  Realme            11 Pro+ 843        618       6         128         64
# 2  Xiaomi  Redmi Note 14 Pro 461        258      16          64         64
# 3    Vivo               V29e 744        837       6         512         48
# 4   Apple  iPhone 16 Pro Max 927        335      12         128        200
#
#    battery_mah  display_size_inch  charging_watt 5g_support       os  \
# 0         6000                6.6             33        Yes  Android
# 1         4500                6.9            100        Yes  Android
# 2         4000                6.8             44        Yes  Android
# 3         4500                6.0             65        Yes  Android
# 4         5000                6.9            100        Yes      iOS
#
#         processor  rating release_month
# 0       Helio G99     3.8      February
# 1       Tensor G4     4.4        August
# 2         A18 Pro     4.1         March
# 3     Exynos 2400     4.1        August
# 4  Dimensity 9300     3.5      February

# %% [markdown]
# #Identificación de Outliers

# %%
sns.boxplot(x=df["rating"])
plt.title("Boxplot de rating")
plt.show()

# %%
sns.boxplot(x=df["price_usd"])
plt.title("Boxplot de Charges")
plt.show()

# %% [markdown]
# #Tratamiento de datos inconsistentes en texto y duplicados.

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [brand, model, price_usd, ram_gb, storage_gb, camera_mp, battery_mah, display_size_inch, charging_watt, 5g_support, os, processor, rating, release_month]
# Index: []

# %%
print(df['display_size_inch'].value_counts())
print(df['release_month'].value_counts())
print(df['brand'].value_counts())
# Out:
# display_size_inch
# 6.6    71
# 6.7    71
# 7.0    65
# 6.1    63
# 5.9    63
# 7.1    62
# 6.0    62
# 6.9    61
# 6.5    58
# 5.6    56
# 6.8    53
# 5.7    53
# 6.3    50
# 6.2    50
# 6.4    50
# 5.8    45
# 7.2    38
# 5.5    29
# Name: count, dtype: int64
# release_month
# April        101
# January       95
# July          93
# October       86
# August        85
# February      84
# June          82
# December      80
# March         77
# November      73
# September     73
# May           71
# Name: count, dtype: int64
# brand
# Vivo       122
# Google     116
# OnePlus    116
# Xiaomi     114
# Oppo       110
# Apple      107
# Realme     105
# Infinix    105
# Samsung    105
# Name: count, dtype: int64

# %% [markdown]
# ##Creación de variables

# %%
def clasificar_ram(ram):
    if ram < 3:
        return "Bajo"
    elif ram == 4:
        return "Medio-bajo"
    elif ram==6:
        return "Medio"
    elif ram==8:
        return "Medio-alto"
    elif ram==12:
        return "Alto"
    elif ram>12:
        return "Premium"


df['Calidad según Ram'] = df['ram_gb'].map(clasificar_ram)
df.head()
# Out:
#     brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 0    Oppo                A98 111        855      16         128        108
# 1  Realme            11 Pro+ 843        618       6         128         64
# 2  Xiaomi  Redmi Note 14 Pro 461        258      16          64         64
# 3    Vivo               V29e 744        837       6         512         48
# 4   Apple  iPhone 16 Pro Max 927        335      12         128        200
#
#    battery_mah  display_size_inch  charging_watt 5g_support       os  \
# 0         6000                6.6             33        Yes  Android
# 1         4500                6.9            100        Yes  Android
# 2         4000                6.8             44        Yes  Android
# 3         4500                6.0             65        Yes  Android
# 4         5000                6.9            100        Yes      iOS
#
#         processor  rating release_month Calidad según Ram
# 0       Helio G99     3.8      February           Premium
# 1       Tensor G4     4.4        August             Medio
# 2         A18 Pro     4.1         March           Premium
# 3     Exynos 2400     4.1        August             Medio
# 4  Dimensity 9300     3.5      February              Alto

# %%
df['Eficiencia bateria'] = round(df['battery_mah']/df["charging_watt"])
df.head()
# Out:
#     brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 0    Oppo                A98 111        855      16         128        108
# 1  Realme            11 Pro+ 843        618       6         128         64
# 2  Xiaomi  Redmi Note 14 Pro 461        258      16          64         64
# 3    Vivo               V29e 744        837       6         512         48
# 4   Apple  iPhone 16 Pro Max 927        335      12         128        200
#
#    battery_mah  display_size_inch  charging_watt 5g_support       os  \
# 0         6000                6.6             33        Yes  Android
# 1         4500                6.9            100        Yes  Android
# 2         4000                6.8             44        Yes  Android
# 3         4500                6.0             65        Yes  Android
# 4         5000                6.9            100        Yes      iOS
#
#         processor  rating release_month Calidad según Ram  Eficiencia bateria
# 0       Helio G99     3.8      February           Premium               182.0
# 1       Tensor G4     4.4        August             Medio                45.0
# 2         A18 Pro     4.1         March           Premium                91.0
# 3     Exynos 2400     4.1        August             Medio                69.0
# 4  Dimensity 9300     3.5      February              Alto                50.0

# %%
df['Porcentaje eficiencia']= round((df['Eficiencia bateria']*100)/333)
df.head()
# Out:
#     brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 0    Oppo                A98 111        855      16         128        108
# 1  Realme            11 Pro+ 843        618       6         128         64
# 2  Xiaomi  Redmi Note 14 Pro 461        258      16          64         64
# 3    Vivo               V29e 744        837       6         512         48
# 4   Apple  iPhone 16 Pro Max 927        335      12         128        200
#
#    battery_mah  display_size_inch  charging_watt 5g_support       os  \
# 0         6000                6.6             33        Yes  Android
# 1         4500                6.9            100        Yes  Android
# 2         4000                6.8             44        Yes  Android
# 3         4500                6.0             65        Yes  Android
# 4         5000                6.9            100        Yes      iOS
#
#         processor  rating release_month Calidad según Ram  Eficiencia bateria  \
# 0       Helio G99     3.8      February           Premium               182.0
# 1       Tensor G4     4.4        August             Medio                45.0
# 2         A18 Pro     4.1         March           Premium                91.0
# 3     Exynos 2400     4.1        August             Medio                69.0
# 4  Dimensity 9300     3.5      February              Alto                50.0
#
#    Porcentaje eficiencia
# 0                   55.0
# 1                   14.0
# 2                   27.0
# 3                   21.0
# 4                   15.0

# %% [markdown]
# #Filtrado y condiciones en Pandas

# %%
#Celulares con calidad de ram Premium o Alta y tienen una calificación mayor o igual a 4.
df[((df['Calidad según Ram']== 'Premium') | (df['Calidad según Ram']=="Alto")) & (df["rating"]>=4)]
# Out:
#        brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 2     Xiaomi  Redmi Note 14 Pro 461        258      16          64         64
# 6    Infinix          GT 20 Pro 112        418      12         256         64
# 7      Apple  iPhone 16 Pro Max 232       1447      16          64         64
# 13    Realme           Narzo 70 620       1192      12         256         12
# 19   OnePlus         OnePlus 12 729        127      16         256        200
# ..       ...                    ...        ...     ...         ...        ...
# 979   Google            Pixel 9 523        202      16         256         64
# 983     Vivo               Y200 568       1328      16         256         12
# 986  Samsung   Galaxy S24 Ultra 502       1368      16          64         50
# 990   Google       Pixel Fold 2 610       1224      12          64         48
# 991   Realme            11 Pro+ 634        629      16        1024         12
#
#      battery_mah  display_size_inch  charging_watt 5g_support       os  \
# 2           4000                6.8             44        Yes  Android
# 6           6000                6.9             44         No  Android
# 7           4500                6.7             33        Yes      iOS
# 13          4000                6.2             33         No  Android
# 19          5500                5.7             44        Yes  Android
# ..           ...                ...            ...        ...      ...
# 979         5000                6.0             33         No  Android
# 983         6000                5.7             18         No  Android
# 986         5500                5.6            120         No  Android
# 990         5000                6.0             33         No  Android
# 991         4000                6.8             65         No  Android
#
#                processor  rating release_month Calidad según Ram  \
# 2                A18 Pro     4.1         March           Premium
# 6            Exynos 2400     4.1         April              Alto
# 7            Exynos 2400     4.7      November           Premium
# 13    Snapdragon 8 Gen 3     4.7       October              Alto
# 19   Snapdragon 7+ Gen 2     5.0       January           Premium
# ..                   ...     ...           ...               ...
# 979            Helio G99     4.0         April           Premium
# 983   Snapdragon 8 Gen 3     4.2         April           Premium
# 986   Snapdragon 6 Gen 1     4.9     September           Premium
# 990   Snapdragon 8 Gen 3     4.3     September              Alto
# 991       Dimensity 9300     4.9           May           Premium
#
#      Eficiencia bateria  Porcentaje eficiencia
# 2                  91.0                   27.0
# 6                 136.0                   41.0
# 7                 136.0                   41.0
# 13                121.0                   36.0
# 19                125.0                   38.0
# ..                  ...                    ...
# 979               152.0                   46.0
# 983               333.0                  100.0
# 986                46.0                   14.0
# 990               152.0                   46.0
# 991                62.0                   19.0
#
# [253 rows x 17 columns]

# %%
#Celulares con un valor mayor a 815, que soporte 5G y tengan capacidad almacenamiento mayor a 128GB
df[(df['price_usd']>815)&(df['5g_support']=="Yes")&(df['storage_gb']>128)]
# Out:
#        brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 3       Vivo               V29e 744        837       6         512         48
# 8    Infinix             Hot 40 111       1354       6        1024         12
# 10   Samsung     Galaxy Z Fold6 423       1093       8        1024        200
# 17   Samsung     Galaxy Z Fold6 163       1339       6         512        200
# 23    Realme            GT Neo 6 18       1404      16        1024         50
# ..       ...                    ...        ...     ...         ...        ...
# 962    Apple  iPhone 16 Pro Max 533       1467       8        1024         64
# 969    Apple           iPhone 14 59       1386       8         256        200
# 974  Infinix             Zero 30 20       1222       8        1024         48
# 980   Xiaomi            Poco F6 856        909       6         256        108
# 995   Google             Pixel 7a 2        961       8         256         12
#
#      battery_mah  display_size_inch  charging_watt 5g_support       os  \
# 3           4500                6.0             65        Yes  Android
# 8           5500                5.7             18        Yes  Android
# 10          4000                5.6            100        Yes  Android
# 17          4500                6.2            120        Yes  Android
# 23          4000                6.6            100        Yes  Android
# ..           ...                ...            ...        ...      ...
# 962         5500                6.8             65        Yes      iOS
# 969         4000                5.6             65        Yes      iOS
# 974         4000                6.4            120        Yes  Android
# 980         4000                6.7             44        Yes  Android
# 995         4000                5.9             44        Yes  Android
#
#                processor  rating release_month Calidad según Ram  \
# 3            Exynos 2400     4.1        August             Medio
# 8              Tensor G4     4.0          July             Medio
# 10    Snapdragon 8 Gen 3     4.1         April        Medio-alto
# 17   Snapdragon 7+ Gen 2     4.7           May             Medio
# 23             Tensor G4     4.7         April           Premium
# ..                   ...     ...           ...               ...
# 962       Dimensity 9300     3.7          July        Medio-alto
# 969            Helio G99     3.9     September        Medio-alto
# 974   Snapdragon 6 Gen 1     5.0       October        Medio-alto
# 980            Tensor G4     3.6         March             Medio
# 995            Helio G99     4.0      November        Medio-alto
#
#      Eficiencia bateria  Porcentaje eficiencia
# 3                  69.0                   21.0
# 8                 306.0                   92.0
# 10                 40.0                   12.0
# 17                 38.0                   11.0
# 23                 40.0                   12.0
# ..                  ...                    ...
# 962                85.0                   26.0
# 969                62.0                   19.0
# 974                33.0                   10.0
# 980                91.0                   27.0
# 995                91.0                   27.0
#
# [145 rows x 17 columns]

# %%
#Celulares marca Samsung o Apple y una calificación mayor a 4.5.
x=df[((df['brand']=="Samsung")|(df['brand']=="Apple"))&(df['rating']>4.5)]
x
# Out:
#        brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 7      Apple  iPhone 16 Pro Max 232       1447      16          64         64
# 17   Samsung     Galaxy Z Fold6 163       1339       6         512        200
# 22     Apple          iPhone 14 328        868       4         512         12
# 25   Samsung         Galaxy S24 662        238      16        1024        108
# 39     Apple  iPhone 16 Pro Max 362        528       4         512         50
# ..       ...                    ...        ...     ...         ...        ...
# 914  Samsung         Galaxy S24 567        179       4        1024         64
# 919    Apple       iPhone 16 Pro 19        442       6         256        108
# 955  Samsung          Galaxy S24 24        894      12         128         48
# 964    Apple       iPhone 16 Pro 99        993       4         128         64
# 986  Samsung   Galaxy S24 Ultra 502       1368      16          64         50
#
#      battery_mah  display_size_inch  charging_watt 5g_support       os  \
# 7           4500                6.7             33        Yes      iOS
# 17          4500                6.2            120        Yes  Android
# 22          4500                7.2             44         No      iOS
# 25          5000                6.1             33         No  Android
# 39          5500                7.2            120         No      iOS
# ..           ...                ...            ...        ...      ...
# 914         5000                5.6             44         No  Android
# 919         5500                5.8             33         No      iOS
# 955         5500                6.9            100         No  Android
# 964         5000                5.8             65        Yes      iOS
# 986         5500                5.6            120         No  Android
#
#                processor  rating release_month Calidad según Ram  \
# 7            Exynos 2400     4.7      November           Premium
# 17   Snapdragon 7+ Gen 2     4.7           May             Medio
# 22    Snapdragon 6 Gen 1     4.6      December        Medio-bajo
# 25    Snapdragon 8 Gen 3     5.0      November           Premium
# 39    Snapdragon 8 Gen 3     4.6       January        Medio-bajo
# ..                   ...     ...           ...               ...
# 914       Dimensity 9300     5.0      February        Medio-bajo
# 919            Tensor G4     4.9         April             Medio
# 955              A18 Pro     4.8     September              Alto
# 964       Dimensity 9300     4.6     September        Medio-bajo
# 986   Snapdragon 6 Gen 1     4.9     September           Premium
#
#      Eficiencia bateria  Porcentaje eficiencia
# 7                 136.0                   41.0
# 17                 38.0                   11.0
# 22                102.0                   31.0
# 25                152.0                   46.0
# 39                 46.0                   14.0
# ..                  ...                    ...
# 914               114.0                   34.0
# 919               167.0                   50.0
# 955                55.0                   17.0
# 964                77.0                   23.0
# 986                46.0                   14.0
#
# [66 rows x 17 columns]

# %%
#Celulares que fueron lanzados al mercado en Noviembre y que la calidad de ram sea Premium.
df[(df['release_month']=="November")&(df['Calidad según Ram']=="Premium")]
# Out:
#        brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 7      Apple  iPhone 16 Pro Max 232       1447      16          64         64
# 25   Samsung         Galaxy S24 662        238      16        1024        108
# 60    Xiaomi  Redmi Note 14 Pro 603        241      16         512         48
# 103   Google       Pixel Fold 2 375        994      16        1024         48
# 327     Vivo              Y100A 175       1331      16         128         48
# 365   Google            Pixel 8 659        445      16         256         50
# 436   Xiaomi        Mi 13 Ultra 150        193      16          64         48
# 520   Realme            GT Neo 6 43       1044      16        1024         64
# 612    Apple          iPhone 14 583       1291      16        1024         64
# 624  OnePlus         OnePlus 13 863        830      16          64         48
# 862  Infinix            Zero 30 132        646      16         128         64
# 972     Vivo                V30 425        537      16         256         50
# 985   Google            Pixel 9 228        726      16          64         48
# 996  OnePlus        OnePlus 13R 423        158      16          64         64
#
#      battery_mah  display_size_inch  charging_watt 5g_support       os  \
# 7           4500                6.7             33        Yes      iOS
# 25          5000                6.1             33         No  Android
# 60          5500                6.5            100         No  Android
# 103         6000                6.6             65         No  Android
# 327         6000                6.5            100        Yes  Android
# 365         4000                6.1             33         No  Android
# 436         5500                6.6             65        Yes  Android
# 520         6000                6.9             33         No  Android
# 612         4500                6.8            100        Yes      iOS
# 624         6000                5.6             33        Yes  Android
# 862         6000                6.5            100        Yes  Android
# 972         4500                6.7             33        Yes  Android
# 985         5500                6.6             44         No  Android
# 996         5500                5.6             65        Yes  Android
#
#               processor  rating release_month Calidad según Ram  \
# 7           Exynos 2400     4.7      November           Premium
# 25   Snapdragon 8 Gen 3     5.0      November           Premium
# 60   Snapdragon 6 Gen 1     4.4      November           Premium
# 103             A18 Pro     4.3      November           Premium
# 327      Dimensity 9300     3.7      November           Premium
# 365  Snapdragon 8 Gen 3     4.2      November           Premium
# 436         Exynos 2400     3.8      November           Premium
# 520           Tensor G4     4.7      November           Premium
# 612      Dimensity 9300     3.9      November           Premium
# 624  Snapdragon 8 Gen 3     4.2      November           Premium
# 862           Helio G99     4.4      November           Premium
# 972         Exynos 2400     4.8      November           Premium
# 985  Snapdragon 8 Gen 3     3.8      November           Premium
# 996      Dimensity 9300     3.5      November           Premium
#
#      Eficiencia bateria  Porcentaje eficiencia
# 7                 136.0                   41.0
# 25                152.0                   46.0
# 60                 55.0                   17.0
# 103                92.0                   28.0
# 327                60.0                   18.0
# 365               121.0                   36.0
# 436                85.0                   26.0
# 520               182.0                   55.0
# 612                45.0                   14.0
# 624               182.0                   55.0
# 862                60.0                   18.0
# 972               136.0                   41.0
# 985               125.0                   38.0
# 996                85.0                   26.0

# %%
#Las 3 marcas con los mejores procesadores y con un porcentaje de eficiencia mayor a 75.
df[((df['processor']=="Snapdragon 8 Gen 3")| (df['processor']=="A18 Pro")| (df['processor']=="Dimensity 9300"))& (df['Porcentaje eficiencia']>75) ]
# Out:
#        brand               model  price_usd  ram_gb  storage_gb  camera_mp  \
# 49   Infinix         Smart 8 176       1286      16          64         48
# 58    Google         Pixel 9 567       1119      12        1024        108
# 87      Oppo         Reno 11 946       1025      16         512        200
# 100  OnePlus      OnePlus 12 755       1278      12         128        200
# 101    Apple       iPhone 16 945        356       6         256         12
# 116  Samsung  Galaxy Z Fold6 878        385       6          64         48
# 150  OnePlus  Nord CE 4 Lite 268        262       8        1024        108
# 228  Samsung      Galaxy A75 639       1095      12        1024        108
# 245     Vivo              V30 96        205       6         512         12
# 287    Apple   iPhone 16 Pro 711       1477      12         512        200
# 308     Oppo         F27 Pro 263        691       8        1024        200
# 309     Oppo         Find X7 246        224       6         512         12
# 331     Vivo        X100 Pro 954        883       8         512         64
# 359  Samsung  Galaxy Z Fold6 554       1049       4        1024         48
# 372    Apple       iPhone 15 776       1210      16          64         50
# 448  Samsung   Galaxy Z Fold6 52        900      12         128        200
# 449   Google        Pixel 7a 315        980      16         512         48
# 484  Infinix       GT 20 Pro 236       1021      16         512         50
# 523     Vivo        X100 Pro 935       1495       6          64         64
# 547  Samsung      Galaxy A75 456       1034      16          64         48
# 626   Google        Pixel 7a 786       1458      12         128        200
# 641  Infinix         Smart 8 912       1019       4         256        200
# 670   Google        Pixel 7a 526        707      12          64        200
# 721     Vivo            Y200 244       1397       6         128         48
# 732     Vivo        X100 Pro 537        189       8         512         12
# 751   Xiaomi     Mi 13 Ultra 708       1229       8          64         48
# 791  Samsung  Galaxy Z Fold6 135        443       6         512         48
# 894     Vivo            V29e 299       1267       4         512        108
# 925   Xiaomi           Mi 14 163       1039       8         256         50
# 976   Realme        Narzo 70 661       1034      12         512         64
# 983     Vivo            Y200 568       1328      16         256         12
#
#      battery_mah  display_size_inch  charging_watt 5g_support       os  \
# 49          5000                6.0             18         No  Android
# 58          5000                6.1             18         No  Android
# 87          6000                6.5             18        Yes  Android
# 100         5000                6.5             18         No  Android
# 101         6000                6.8             18         No      iOS
# 116         6000                6.0             18         No  Android
# 150         5000                6.9             18        Yes  Android
# 228         5500                7.1             18        Yes  Android
# 245         6000                7.1             18        Yes  Android
# 287         6000                5.7             18         No      iOS
# 308         6000                6.7             18        Yes  Android
# 309         5000                6.8             18        Yes  Android
# 331         5000                7.1             18         No  Android
# 359         5500                6.1             18        Yes  Android
# 372         5500                6.7             18        Yes      iOS
# 448         5000                7.2             18        Yes  Android
# 449         6000                7.1             18         No  Android
# 484         6000                6.5             18        Yes  Android
# 523         5000                5.6             18        Yes  Android
# 547         6000                6.1             18         No  Android
# 626         5500                6.7             18         No  Android
# 641         6000                6.8             18         No  Android
# 670         5000                6.9             18        Yes  Android
# 721         6000                5.8             18        Yes  Android
# 732         5000                6.8             18         No  Android
# 751         5000                6.3             18        Yes  Android
# 791         5500                6.3             18        Yes  Android
# 894         5000                6.7             18         No  Android
# 925         6000                6.0             18        Yes  Android
# 976         5000                7.0             18         No  Android
# 983         6000                5.7             18         No  Android
#
#               processor  rating release_month Calidad según Ram  \
# 49       Dimensity 9300     3.6     September           Premium
# 58              A18 Pro     3.8        August              Alto
# 87              A18 Pro     4.3        August           Premium
# 100             A18 Pro     3.9          June              Alto
# 101      Dimensity 9300     4.6        August             Medio
# 116             A18 Pro     4.9       January             Medio
# 150             A18 Pro     4.3        August        Medio-alto
# 228      Dimensity 9300     4.9         March              Alto
# 245             A18 Pro     4.6      December             Medio
# 287      Dimensity 9300     5.0        August              Alto
# 308      Dimensity 9300     5.0          June        Medio-alto
# 309             A18 Pro     4.3      November             Medio
# 331      Dimensity 9300     4.8       January        Medio-alto
# 359  Snapdragon 8 Gen 3     4.8         March        Medio-bajo
# 372             A18 Pro     4.2         April           Premium
# 448             A18 Pro     3.7         April              Alto
# 449      Dimensity 9300     3.7      December           Premium
# 484      Dimensity 9300     5.0           May           Premium
# 523  Snapdragon 8 Gen 3     4.9         April             Medio
# 547  Snapdragon 8 Gen 3     4.0       January           Premium
# 626  Snapdragon 8 Gen 3     4.4           May              Alto
# 641  Snapdragon 8 Gen 3     3.6         April        Medio-bajo
# 670  Snapdragon 8 Gen 3     4.8           May              Alto
# 721  Snapdragon 8 Gen 3     3.7           May             Medio
# 732      Dimensity 9300     4.1      December        Medio-alto
# 751             A18 Pro     3.7      December        Medio-alto
# 791      Dimensity 9300     4.1      February             Medio
# 894      Dimensity 9300     4.7     September        Medio-bajo
# 925      Dimensity 9300     4.6      December        Medio-alto
# 976      Dimensity 9300     3.8       October              Alto
# 983  Snapdragon 8 Gen 3     4.2         April           Premium
#
#      Eficiencia bateria  Porcentaje eficiencia
# 49                278.0                   83.0
# 58                278.0                   83.0
# 87                333.0                  100.0
# 100               278.0                   83.0
# 101               333.0                  100.0
# 116               333.0                  100.0
# 150               278.0                   83.0
# 228               306.0                   92.0
# 245               333.0                  100.0
# 287               333.0                  100.0
# 308               333.0                  100.0
# 309               278.0                   83.0
# 331               278.0                   83.0
# 359               306.0                   92.0
# 372               306.0                   92.0
# 448               278.0                   83.0
# 449               333.0                  100.0
# 484               333.0                  100.0
# 523               278.0                   83.0
# 547               333.0                  100.0
# 626               306.0                   92.0
# 641               333.0                  100.0
# 670               278.0                   83.0
# 721               333.0                  100.0
# 732               278.0                   83.0
# 751               278.0                   83.0
# 791               306.0                   92.0
# 894               278.0                   83.0
# 925               333.0                  100.0
# 976               278.0                   83.0
# 983               333.0                  100.0

# %% [markdown]
# #Agrupación con groupby:

# %%
#Agrupación de las marcas con el precio teniendo en cuenta el mínimo, máximo y su promedio.
df.groupby("brand")["price_usd"].agg(["min", "max", "mean"])
# Out:
#          min   max        mean
# brand
# Apple    126  1477  835.691589
# Google   121  1480  808.060345
# Infinix  109  1485  839.171429
# OnePlus  118  1497  812.250000
# Oppo     102  1498  826.327273
# Realme   101  1433  771.780952
# Samsung  142  1498  791.723810
# Vivo     112  1499  807.901639
# Xiaomi   105  1496  827.736842

# %%
#Calificación de los celulares en comparación a su procesador teniendo en cuenta su mínimo, máximo y promedio.
df.groupby("processor")["rating"].agg(["min", "max", "mean"])
# Out:
#                      min  max      mean
# processor
# A18 Pro              3.5  5.0  4.253571
# Dimensity 9300       3.5  5.0  4.247101
# Exynos 2400          3.5  5.0  4.228226
# Helio G99            3.5  5.0  4.225781
# Snapdragon 6 Gen 1   3.5  5.0  4.235593
# Snapdragon 7+ Gen 2  3.5  5.0  4.216522
# Snapdragon 8 Gen 3   3.5  5.0  4.225758
# Tensor G4            3.5  5.0  4.208271

# %%
#Agrupación de las marcas con su eficiencia de bateria, ordenadas de mayor a menor.
df.groupby("brand")["Eficiencia bateria"].mean().sort_values(ascending=False)
# Out:
# brand
# Samsung    130.095238
# Infinix    129.028571
# Google     121.137931
# Vivo       119.147541
# Xiaomi     118.043860
# Realme     114.380952
# OnePlus    111.051724
# Apple      110.551402
# Oppo       110.409091
# Name: Eficiencia bateria, dtype: float64

# %%
#Cantidad de celulares con la eficiencia de bateria.
df.groupby("Eficiencia bateria").size()
# Out:
# Eficiencia bateria
# 33.0     30
# 38.0     40
# 40.0     35
# 42.0     38
# 45.0     25
# 46.0     34
# 50.0     64
# 55.0     32
# 60.0     35
# 62.0     40
# 69.0     29
# 77.0     27
# 85.0     48
# 91.0     30
# 92.0     36
# 102.0    27
# 114.0    37
# 121.0    27
# 125.0    42
# 136.0    64
# 152.0    30
# 167.0    26
# 182.0    35
# 222.0    41
# 250.0    29
# 278.0    37
# 306.0    21
# 333.0    41
# dtype: int64

# %%
#Lista de las marcas con el promedio de su calificación, de mayor a menor.
df.groupby("brand")["rating"].mean().sort_values(ascending=False)
# Out:
# brand
# Realme     4.312381
# Samsung    4.291429
# Infinix    4.226667
# Oppo       4.225455
# Apple      4.223364
# Xiaomi     4.216667
# Vivo       4.209016
# OnePlus    4.196552
# Google     4.181034
# Name: rating, dtype: float64

# %%
#Cantidad de celulares que soportan y no soportan 5G.
df.groupby("5g_support").size()
# Out:
# 5g_support
# No     497
# Yes    503
# dtype: int64

# %%
#Cantidad de celulares que tiene una calidad de ram.
df.groupby("Calidad según Ram").size()
# Out:
# Calidad según Ram
# Alto          200
# Medio         210
# Medio-alto    188
# Medio-bajo    202
# Premium       200
# dtype: int64

# %% [markdown]
# #Visualizaciones:

# %%
#Diagrama de barras del promedio de los precios de las marcas.
mean_prices = df.groupby("brand")["price_usd"].mean()

plt.figure(figsize=(8,5))
plt.bar(mean_prices.index, mean_prices.values)
plt.xlabel("Brand")
plt.ylabel("Precio Promedio (USD)")
plt.title("Precio promedio por marca")
plt.tight_layout()
plt.show()

# %%
#Mapa de calor del precio de los celulares teniendo en cuenta su marca y mes de lanzamiento.
grouped = df.groupby(["brand", "release_month"])["price_usd"].mean().reset_index()
pivot = grouped.pivot(index="brand", columns="release_month", values="price_usd")

plt.figure(figsize=(11,5))
plt.imshow(pivot, aspect="auto")
plt.xticks(range(len(pivot.columns)), pivot.columns)
plt.yticks(range(len(pivot.index)), pivot.index)
plt.title("Precio promedio por marca y mes de lanzamiento")
plt.colorbar(label="Precio promedio (USD)")
plt.tight_layout()
plt.show()

# %%
#Scatter plot del precio en base a la calidad de la ram.
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(14, 8))
colors = {
    'Premium': '#FFD700',
    'Alto': '#FF6B6B',
    'Medio-alto': '#4ECDC4',
    'Medio': '#95E1D3',
    'Medio-bajo': '#A8E6CF',
    "Bajo":"#0525EEB"
}

for segment in df['Calidad según Ram'].unique():
    segment_data = df[df['Calidad según Ram'] == segment]
    ax.scatter(segment_data['ram_gb'],
               segment_data['price_usd'],
               s=80,
               alpha=0.5,
               c=colors[segment],
               label=segment,
               edgecolors='none')

ax.set_xlabel('RAM (GB)', fontsize=13, fontweight='bold')
ax.set_ylabel('Precio (USD)', fontsize=13, fontweight='bold')
ax.set_title('Relación entre Precio y RAM según Segmento de Calidad\n(n=1000 smartphones)',
             fontsize=15, fontweight='bold', pad=20)
ax.legend(title='Segmento', title_fontsize=12, fontsize=11,
          loc='upper left', framealpha=0.9)
ax.grid(True, alpha=0.3)

z = np.polyfit(df['ram_gb'], df['price_usd'], 1)
p = np.poly1d(z)
ax.plot(df['ram_gb'], p(df['ram_gb']),
        "r--", alpha=0.7, linewidth=3, label='Tendencia general')

plt.tight_layout()
plt.show()

# %%
#Diagrama de barras del costo promedio en base al almacenamiento(GB) por marca.
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(14, 7))

all_brands = df['brand'].unique()

colors_list = plt.cm.tab20(np.linspace(0, 1, len(all_brands)))
brand_colors = {brand: colors_list[i] for i, brand in enumerate(all_brands)}

known_colors = {
    'Apple': '#A2AAAD',
    'Samsung': '#1428A0',
    'Google': '#4285F4',
    'OnePlus': '#F50514',
    'Oppo': '#00A862',
    'Infinix': '#FF6B35',
    'Realme': '#FFCC00',
    'Xiaomi': '#FF6900',
    'Motorola': '#0066CC',
    'Vivo': '#1157B0'
}

brand_colors.update({k: v for k, v in known_colors.items() if k in all_brands})

df['precio_por_gb'] = df['price_usd']

top_brands = df['brand'].value_counts().head(15).index
df_top = df[df['brand'].isin(top_brands)]

precio_por_marca = df_top.groupby('brand')['precio_por_gb'].mean().sort_values(ascending=False)

bars = ax.bar(range(len(precio_por_marca)),
              precio_por_marca.values,
              color=[brand_colors.get(brand, '#808080') for brand in precio_por_marca.index],
              alpha=0.8,
              edgecolor='black',
              linewidth=1.5)

for i, (brand, value) in enumerate(precio_por_marca.items()):
    ax.text(i, value + (precio_por_marca.max() * 0.02),
            f'${value:.2f}',
            ha='center', va='bottom', fontweight='bold', fontsize=10)

ax.set_xlabel('Marca', fontsize=13, fontweight='bold')
ax.set_ylabel('Precio en USD', fontsize=13, fontweight='bold')
ax.set_title('Costo Promedio por GB de Almacenamiento por Marca\n(Top 15 marcas - n=1000 smartphones)',
             fontsize=14, fontweight='bold', pad=20)
ax.set_xticks(range(len(precio_por_marca)))
ax.set_xticklabels(precio_por_marca.index, rotation=45, ha='right', fontsize=10)
ax.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# %%
#Calificación promedio en base al procesador.
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(12, 10))

top_processors = df['processor'].value_counts().head(15).index
df_top = df[df['processor'].isin(top_processors)]

rating_por_procesador = df_top.groupby('processor')['rating'].mean().sort_values(ascending=False)

colors = plt.cm.RdYlGn(np.linspace(0.3, 0.9, len(rating_por_procesador)))

bars = ax.barh(range(len(rating_por_procesador)),
               rating_por_procesador.values,
               color=colors,
               alpha=0.8,
               edgecolor='black',
               linewidth=1.5)

for i, (processor, value) in enumerate(rating_por_procesador.items()):
    count = df_top[df_top['processor'] == processor].shape[0]
    ax.text(value + 0.05, i,
            f'{value:.2f} (n={count})',
            va='center', fontweight='bold', fontsize=10)

ax.set_ylabel('Procesador', fontsize=13, fontweight='bold')
ax.set_xlabel('Rating Promedio', fontsize=13, fontweight='bold')
ax.set_title('Rating Promedio por Procesador\n(Top 15 procesadores más comunes - n=1000 smartphones)',
             fontsize=14, fontweight='bold', pad=20)
ax.set_yticks(range(len(rating_por_procesador)))
ax.set_yticklabels(rating_por_procesador.index, fontsize=10)
ax.set_xlim(0, 5.5)
ax.grid(True, alpha=0.3, axis='x')

ax.axvline(x=4.0, color='red', linestyle='--', linewidth=2, alpha=0.6, label='Rating 4.0 (Bueno)')
ax.legend(fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# #Conclusiones
# ###1. El proceso de limpieza y depuración del dataset permitió garantizar la calidad y confiabilidad del análisis, dado que se identificó que no había ningún dato faltante y se eliminaron variables irrelevantes, como year. Esta fue fundamental para asegurar que los resultados posteriores se basaran en datos consistentes y estructurados adecuadamente.
# ###2. Se realizó una búsqueda de los procesadores, evaluando características, funcionamiento y ranking en el mercado, esto permitió identificar que los celulares equipados con procesadores de mayor rendimiento tienden a ubicarse dentro de la gama alta, lo cual incrementa significativamente su valor comercial. Esto confirma la importancia del procesador como componente determinante en el desempeño general del dispositivo móvil.
# ###3. La identificación de outliers en variables como memoria, cámaras y potencia de carga evidenció la presencia de dispositivos con especificaciones excepcionalmente elevadas, propios del segmento premium. Aunque estos valores se alejan de la tendencia general, representan productos reales del mercado y no errores en los datos, por lo que aportan información valiosa sobre los extremos del comportamiento del sector. Se concluyo, que no existen outliers.
# ###4. Los filtros aplicados sobre el dataset facilitaron la identificación de patrones relevantes, permitiendo segmentar los dispositivos según sus características principales, tales como precio, memoria y prestaciones técnicas. Gracias a estas filtraciones fue posible observar con claridad la diferenciación entre gamas baja, media y alta, así como reconocer modelos que destacan dentro de cada categoría.
# ###5. Se evidenció una notable diversidad en los precios de los dispositivos móviles, lo que demuestra la amplia oferta existente en el mercado global. No obstante, el análisis reveló que un mayor precio no se relaciona necesariamente con un mejor rating, lo cual sugiere que la percepción del consumidor puede depender de factores adicionales más allá del costo del dispositivo.

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- --------------------
# absl-py                                  1.4.0
# absolufy-imports                         0.3.1
# accelerate                               1.11.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.2
# aiosignal                                1.4.0
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.17.1
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# antlr4-python3-runtime                   4.9.3
# anyio                                    4.11.0
# anywidget                                0.9.19
# argon2-cffi                              25.1.0
# argon2-cffi-bindings                     25.1.0
# array_record                             0.8.2
# arrow                                    1.4.0
# arviz                                    0.22.0
# astropy                                  7.1.1
# astropy-iers-data                        0.2025.11.10.0.38.31
# astunparse                               1.6.3
# atpublic                                 5.1
# attrs                                    25.4.0
# audioread                                3.1.0
# Authlib                                  1.6.5
# autograd                                 1.8.0
# babel                                    2.17.0
# backcall                                 0.2.0
# beartype                                 0.22.5
# beautifulsoup4                           4.13.5
# betterproto                              2.0.0b6
# bigframes                                2.28.0
# bigquery-magics                          0.10.3
# bleach                                   6.3.0
# blinker                                  1.9.0
# blis                                     1.3.0
# blobfile                                 3.1.0
# blosc2                                   3.11.0
# bokeh                                    3.7.3
# Bottleneck                               1.4.2
# bqplot                                   0.12.45
# branca                                   0.8.2
# brotli                                   1.2.0
# build                                    1.3.0
# CacheControl                             0.14.3
# cachetools                               5.5.2
# catalogue                                2.0.10
# certifi                                  2025.10.5
# cffi                                     2.0.0
# chardet                                  5.2.0
# charset-normalizer                       3.4.4
# chex                                     0.1.90
# clarabel                                 0.11.1
# click                                    8.3.0
# cloudpathlib                             0.23.0
# cloudpickle                              3.1.2
# cmake                                    3.31.6
# cmdstanpy                                1.3.0
# colorcet                                 3.1.0
# colorlover                               0.3.0
# colour                                   0.1.5
# community                                1.0.0b1
# confection                               0.1.5
# cons                                     0.4.7
# contourpy                                1.3.3
# cramjam                                  2.11.0
# cryptography                             43.0.3
# cuda-bindings                            12.9.4
# cuda-core                                0.3.2
# cuda-pathfinder                          1.3.2
# cuda-python                              12.9.4
# cuda-toolkit                             12.9.1
# cudf-cu12                                25.10.0
# cudf-polars-cu12                         25.10.0
# cufflinks                                0.17.3
# cuml-cu12                                25.10.0
# cupy-cuda12x                             13.6.0
# curl_cffi                                0.13.0
# cvxopt                                   1.3.2
# cvxpy                                    1.6.7
# cycler                                   0.12.1
# cyipopt                                  1.5.0
# cymem                                    2.0.11
# Cython                                   3.0.12
# dask                                     2025.9.1
# dask-cuda                                25.10.0
# dask-cudf-cu12                           25.10.0
# dataproc-spark-connect                   0.8.3
# datasets                                 4.0.0
# db-dtypes                                1.4.4
# dbus-python                              1.2.18
# debugpy                                  1.8.15
# decorator                                4.4.2
# defusedxml                               0.7.1
# diffusers                                0.35.2
# dill                                     0.3.8
# distributed                              2025.9.1
# distributed-ucxx-cu12                    0.46.0
# distro                                   1.9.0
# dlib                                     19.24.6
# dm-tree                                  0.1.9
# docstring_parser                         0.17.0
# docutils                                 0.21.2
# dopamine_rl                              4.1.2
# duckdb                                   1.3.2
# earthengine-api                          1.5.24
# easydict                                 1.13
# editdistance                             0.8.1
# eerepr                                   0.1.2
# einops                                   0.8.1
# en_core_web_sm                           3.8.0
# entrypoints                              0.4
# et_xmlfile                               2.0.0
# etils                                    1.13.0
# etuples                                  0.3.10
# Farama-Notifications                     0.0.4
# fastai                                   2.8.5
# fastapi                                  0.121.1
# fastcore                                 1.8.16
# fastdownload                             0.0.7
# fastjsonschema                           2.21.2
# fastprogress                             1.0.3
# fastrlock                                0.8.3
# fasttransform                            0.0.2
# ffmpy                                    1.0.0
# filelock                                 3.20.0
# firebase-admin                           6.9.0
# Flask                                    3.1.2
# flatbuffers                              25.9.23
# flax                                     0.10.7
# folium                                   0.20.0
# fonttools                                4.60.1
# fqdn                                     1.5.1
# frozendict                               2.4.6
# frozenlist                               1.8.0
# fsspec                                   2025.3.0
# future                                   1.0.0
# gast                                     0.6.0
# gcsfs                                    2025.3.0
# GDAL                                     3.8.4
# gdown                                    5.2.0
# geemap                                   0.35.3
# geocoder                                 1.38.1
# geographiclib                            2.1
# geopandas                                1.1.1
# geopy                                    2.4.1
# gin-config                               0.5.0
# gitdb                                    4.0.12
# GitPython                                3.1.45
# glob2                                    0.7
# google                                   2.0.3
# google-adk                               1.17.0
# google-ai-generativelanguage             0.6.15
# google-api-core                          2.28.1
# google-api-python-client                 2.187.0
# google-auth                              2.38.0
# google-auth-httplib2                     0.2.1
# google-auth-oauthlib                     1.2.3
# google-cloud-aiplatform                  1.126.1
# google-cloud-appengine-logging           1.7.0
# google-cloud-audit-log                   0.4.0
# google-cloud-bigquery                    3.38.0
# google-cloud-bigquery-connection         1.19.0
# google-cloud-bigquery-storage            2.34.0
# google-cloud-bigtable                    2.34.0
# google-cloud-core                        2.5.0
# google-cloud-dataproc                    5.23.0
# google-cloud-datastore                   2.21.0
# google-cloud-discoveryengine             0.13.12
# google-cloud-firestore                   2.21.0
# google-cloud-functions                   1.21.0
# google-cloud-language                    2.18.0
# google-cloud-logging                     3.12.1
# google-cloud-monitoring                  2.28.0
# google-cloud-resource-manager            1.15.0
# google-cloud-secret-manager              2.25.0
# google-cloud-spanner                     3.59.0
# google-cloud-speech                      2.34.0
# google-cloud-storage                     2.19.0
# google-cloud-trace                       1.17.0
# google-cloud-translate                   3.23.0
# google-colab                             1.0.0
# google-crc32c                            1.7.1
# google-genai                             1.49.0
# google-generativeai                      0.8.5
# google-pasta                             0.2.0
# google-resumable-media                   2.7.2
# googleapis-common-protos                 1.72.0
# googledrivedownloader                    1.1.0
# gradio                                   5.49.1
# gradio_client                            1.13.3
# graphviz                                 0.21
# greenlet                                 3.2.4
# groovy                                   0.1.2
# grpc-google-iam-v1                       0.14.3
# grpc-interceptor                         0.15.4
# grpcio                                   1.76.0
# grpcio-status                            1.71.2
# grpclib                                  0.4.8
# gspread                                  6.2.1
# gspread-dataframe                        4.0.0
# gym                                      0.25.2
# gym-notices                              0.1.0
# gymnasium                                1.2.2
# h11                                      0.16.0
# h2                                       4.3.0
# h5netcdf                                 1.7.3
# h5py                                     3.15.1
# hdbscan                                  0.8.40
# hf_transfer                              0.1.9
# hf-xet                                   1.2.0
# highspy                                  1.12.0
# holidays                                 0.84
# holoviews                                1.22.0
# hpack                                    4.1.0
# html5lib                                 1.1
# httpcore                                 1.0.9
# httpimport                               1.4.1
# httplib2                                 0.31.0
# httpx                                    0.28.1
# httpx-sse                                0.4.3
# huggingface-hub                          0.36.0
# humanize                                 4.14.0
# hyperframe                               6.1.0
# hyperopt                                 0.2.7
# ibis-framework                           9.5.0
# idna                                     3.11
# ImageIO                                  2.37.2
# imageio-ffmpeg                           0.6.0
# imagesize                                1.4.1
# imbalanced-learn                         0.14.0
# immutabledict                            4.2.2
# importlib_metadata                       8.7.0
# importlib_resources                      6.5.2
# imutils                                  0.5.4
# inflect                                  7.5.0
# iniconfig                                2.3.0
# intel-cmplr-lib-ur                       2025.3.1
# intel-openmp                             2025.3.1
# ipyevents                                2.0.4
# ipyfilechooser                           0.6.0
# ipykernel                                6.17.1
# ipyleaflet                               0.20.0
# ipyparallel                              8.8.0
# ipython                                  7.34.0
# ipython-genutils                         0.2.0
# ipython-sql                              0.5.0
# ipytree                                  0.2.2
# ipywidgets                               7.7.1
# isoduration                              20.11.0
# itsdangerous                             2.2.0
# jaraco.classes                           3.4.0
# jaraco.context                           6.0.1
# jaraco.functools                         4.3.0
# jax                                      0.7.2
# jax-cuda12-pjrt                          0.7.2
# jax-cuda12-plugin                        0.7.2
# jaxlib                                   0.7.2
# jeepney                                  0.9.0
# jieba                                    0.42.1
# Jinja2                                   3.1.6
# jiter                                    0.12.0
# joblib                                   1.5.2
# jsonpatch                                1.33
# jsonpickle                               4.1.1
# jsonpointer                              3.0.0
# jsonschema                               4.25.1
# jsonschema-specifications                2025.9.1
# jupyter_client                           7.4.9
# jupyter-console                          6.6.3
# jupyter_core                             5.9.1
# jupyter-events                           0.12.0
# jupyter_kernel_gateway                   2.5.2
# jupyter-leaflet                          0.20.0
# jupyter_server                           2.14.0
# jupyter_server_terminals                 0.5.3
# jupyterlab_pygments                      0.3.0
# jupyterlab_widgets                       3.0.16
# jupytext                                 1.17.3
# kaggle                                   1.7.4.5
# kagglehub                                0.3.13
# keras                                    3.10.0
# keras-hub                                0.21.1
# keras-nlp                                0.21.1
# keyring                                  25.6.0
# keyrings.google-artifactregistry-auth    1.1.2
# kiwisolver                               1.4.9
# langchain                                0.3.27
# langchain-core                           0.3.79
# langchain-text-splitters                 0.3.11
# langsmith                                0.4.42
# lark                                     1.3.1
# launchpadlib                             1.10.16
# lazr.restfulclient                       0.14.4
# lazr.uri                                 1.0.6
# lazy_loader                              0.4
# libclang                                 18.1.1
# libcudf-cu12                             25.10.0
# libcugraph-cu12                          25.10.1
# libcuml-cu12                             25.10.0
# libkvikio-cu12                           25.10.0
# libpysal                                 4.13.0
# libraft-cu12                             25.10.0
# librmm-cu12                              25.10.0
# librosa                                  0.11.0
# libucx-cu12                              1.19.0
# libucxx-cu12                             0.46.0
# lightgbm                                 4.6.0
# linkify-it-py                            2.0.3
# llvmlite                                 0.43.0
# locket                                   1.0.0
# logical-unification                      0.4.7
# lxml                                     5.4.0
# Mako                                     1.3.10
# Markdown                                 3.10
# markdown-it-py                           4.0.0
# MarkupSafe                               3.0.3
# matplotlib                               3.10.0
# matplotlib-inline                        0.2.1
# matplotlib-venn                          1.1.2
# mcp                                      1.21.0
# mdit-py-plugins                          0.5.0
# mdurl                                    0.1.2
# miniKanren                               1.0.5
# missingno                                0.5.2
# mistune                                  3.1.4
# mizani                                   0.13.5
# mkl                                      2025.2.0
# ml_dtypes                                0.5.3
# mlxtend                                  0.23.4
# more-itertools                           10.8.0
# moviepy                                  1.0.3
# mpmath                                   1.3.0
# msgpack                                  1.1.2
# multidict                                6.7.0
# multipledispatch                         1.0.0
# multiprocess                             0.70.16
# multitasking                             0.0.12
# murmurhash                               1.0.13
# music21                                  9.3.0
# namex                                    0.1.0
# narwhals                                 2.11.0
# natsort                                  8.4.0
# nbclassic                                1.3.3
# nbclient                                 0.10.2
# nbconvert                                7.16.6
# nbformat                                 5.10.4
# ndindex                                  1.10.0
# nest-asyncio                             1.6.0
# networkx                                 3.5
# nibabel                                  5.3.2
# nltk                                     3.9.1
# notebook                                 6.5.7
# notebook_shim                            0.2.4
# numba                                    0.60.0
# numba-cuda                               0.19.1
# numexpr                                  2.14.1
# numpy                                    2.0.2
# nvidia-cublas-cu12                       12.6.4.1
# nvidia-cuda-cccl-cu12                    12.9.27
# nvidia-cuda-cupti-cu12                   12.6.80
# nvidia-cuda-nvcc-cu12                    12.9.86
# nvidia-cuda-nvrtc-cu12                   12.6.77
# nvidia-cuda-runtime-cu12                 12.6.77
# nvidia-cudnn-cu12                        9.10.2.21
# nvidia-cufft-cu12                        11.3.0.4
# nvidia-cufile-cu12                       1.11.1.6
# nvidia-curand-cu12                       10.3.7.77
# nvidia-cusolver-cu12                     11.7.1.2
# nvidia-cusparse-cu12                     12.5.4.2
# nvidia-cusparselt-cu12                   0.7.1
# nvidia-ml-py                             13.580.82
# nvidia-nccl-cu12                         2.27.3
# nvidia-nvjitlink-cu12                    12.6.85
# nvidia-nvshmem-cu12                      3.4.5
# nvidia-nvtx-cu12                         12.6.77
# nvtx                                     0.2.13
# nx-cugraph-cu12                          25.10.0
# oauth2client                             4.1.3
# oauthlib                                 3.3.1
# omegaconf                                2.3.0
# openai                                   1.109.1
# opencv-contrib-python                    4.12.0.88
# opencv-python                            4.12.0.88
# opencv-python-headless                   4.12.0.88
# openpyxl                                 3.1.5
# opentelemetry-api                        1.37.0
# opentelemetry-exporter-gcp-logging       1.11.0a0
# opentelemetry-exporter-gcp-monitoring    1.11.0a0
# opentelemetry-exporter-gcp-trace         1.11.0
# opentelemetry-exporter-otlp-proto-common 1.37.0
# opentelemetry-exporter-otlp-proto-http   1.37.0
# opentelemetry-proto                      1.37.0
# opentelemetry-resourcedetector-gcp       1.11.0a0
# opentelemetry-sdk                        1.37.0
# opentelemetry-semantic-conventions       0.58b0
# opt_einsum                               3.4.0
# optax                                    0.2.6
# optree                                   0.17.0
# orbax-checkpoint                         0.11.28
# orjson                                   3.11.4
# osqp                                     1.0.5
# overrides                                7.7.0
# packaging                                25.0
# pandas                                   2.2.2
# pandas-datareader                        0.10.0
# pandas-gbq                               0.30.0
# pandas-stubs                             2.2.2.240909
# pandocfilters                            1.5.1
# panel                                    1.8.3
# param                                    2.2.1
# parso                                    0.8.5
# parsy                                    2.2
# partd                                    1.4.2
# patsy                                    1.0.2
# peewee                                   3.18.3
# peft                                     0.17.1
# pexpect                                  4.9.0
# pickleshare                              0.7.5
# pillow                                   11.3.0
# pip                                      24.1.2
# platformdirs                             4.5.0
# plotly                                   5.24.1
# plotnine                                 0.14.5
# pluggy                                   1.6.0
# plum-dispatch                            2.6.0
# ply                                      3.11
# polars                                   1.31.0
# pooch                                    1.8.2
# portpicker                               1.5.2
# preshed                                  3.0.10
# prettytable                              3.16.0
# proglog                                  0.1.12
# progressbar2                             4.5.0
# prometheus_client                        0.23.1
# promise                                  2.3
# prompt_toolkit                           3.0.52
# propcache                                0.4.1
# prophet                                  1.1.7
# proto-plus                               1.26.1
# protobuf                                 5.29.5
# psutil                                   5.9.5
# psycopg2                                 2.9.11
# psygnal                                  0.15.0
# ptyprocess                               0.7.0
# py-cpuinfo                               9.0.0
# py4j                                     0.10.9.7
# pyarrow                                  18.1.0
# pyasn1                                   0.6.1
# pyasn1_modules                           0.4.2
# pycairo                                  1.29.0
# pycocotools                              2.0.10
# pycparser                                2.23
# pycryptodomex                            3.23.0
# pydantic                                 2.11.10
# pydantic_core                            2.33.2
# pydantic-settings                        2.12.0
# pydata-google-auth                       1.9.1
# pydot                                    3.0.4
# pydotplus                                2.0.2
# PyDrive2                                 1.21.3
# pydub                                    0.25.1
# pyerfa                                   2.0.1.5
# pygame                                   2.6.1
# pygit2                                   1.19.0
# Pygments                                 2.19.2
# PyGObject                                3.42.0
# PyJWT                                    2.10.1
# pylibcudf-cu12                           25.10.0
# pylibcugraph-cu12                        25.10.1
# pylibraft-cu12                           25.10.0
# pymc                                     5.26.1
# pynndescent                              0.5.13
# pyogrio                                  0.11.1
# pyomo                                    6.9.5
# PyOpenGL                                 3.1.10
# pyOpenSSL                                24.2.1
# pyparsing                                3.2.5
# pyperclip                                1.11.0
# pyproj                                   3.7.2
# pyproject_hooks                          1.2.0
# pyshp                                    3.0.2.post1
# PySocks                                  1.7.1
# pyspark                                  3.5.1
# pytensor                                 2.35.1
# pytest                                   8.4.2
# python-apt                               0.0.0
# python-box                               7.3.2
# python-dateutil                          2.9.0.post0
# python-dotenv                            1.2.1
# python-json-logger                       4.0.0
# python-louvain                           0.16
# python-multipart                         0.0.20
# python-slugify                           8.0.4
# python-snappy                            0.7.3
# python-utils                             3.9.1
# pytz                                     2025.2
# pyviz_comms                              3.0.6
# PyWavelets                               1.9.0
# PyYAML                                   6.0.3
# pyzmq                                    26.2.1
# raft-dask-cu12                           25.10.0
# rapids-dask-dependency                   25.10.0
# rapids-logger                            0.1.19
# ratelim                                  0.1.6
# referencing                              0.37.0
# regex                                    2024.11.6
# requests                                 2.32.4
# requests-oauthlib                        2.0.0
# requests-toolbelt                        1.0.0
# requirements-parser                      0.9.0
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rfc3987-syntax                           1.1.0
# rich                                     13.9.4
# rmm-cu12                                 25.10.0
# roman-numerals-py                        3.1.0
# rpds-py                                  0.28.0
# rpy2                                     3.5.17
# rsa                                      4.9.1
# ruff                                     0.14.4
# safehttpx                                0.1.7
# safetensors                              0.6.2
# scikit-image                             0.25.2
# scikit-learn                             1.6.1
# scipy                                    1.16.3
# scooby                                   0.11.0
# scs                                      3.2.9
# seaborn                                  0.13.2
# SecretStorage                            3.4.1
# semantic-version                         2.10.0
# Send2Trash                               1.8.3
# sentence-transformers                    5.1.2
# sentencepiece                            0.2.1
# sentry-sdk                               2.44.0
# setuptools                               75.2.0
# shap                                     0.50.0
# shapely                                  2.1.2
# shellingham                              1.5.4
# simple-parsing                           0.1.7
# simplejson                               3.20.2
# simsimd                                  6.5.3
# six                                      1.17.0
# sklearn-pandas                           2.2.0
# slicer                                   0.0.8
# smart_open                               7.5.0
# smmap                                    5.0.2
# sniffio                                  1.3.1
# snowballstemmer                          3.0.1
# sortedcontainers                         2.4.0
# soundfile                                0.13.1
# soupsieve                                2.8
# soxr                                     1.0.0
# spacy                                    3.8.8
# spacy-legacy                             3.0.12
# spacy-loggers                            1.0.5
# spanner-graph-notebook                   1.1.8
# Sphinx                                   8.2.3
# sphinxcontrib-applehelp                  2.0.0
# sphinxcontrib-devhelp                    2.0.0
# sphinxcontrib-htmlhelp                   2.1.0
# sphinxcontrib-jsmath                     1.0.1
# sphinxcontrib-qthelp                     2.0.0
# sphinxcontrib-serializinghtml            2.0.0
# SQLAlchemy                               2.0.44
# sqlalchemy-spanner                       1.17.1
# sqlglot                                  25.20.2
# sqlparse                                 0.5.3
# srsly                                    2.5.1
# sse-starlette                            3.0.3
# stanio                                   0.5.1
# starlette                                0.49.3
# statsmodels                              0.14.5
# stringzilla                              4.2.3
# stumpy                                   1.13.0
# sympy                                    1.13.3
# tables                                   3.10.2
# tabulate                                 0.9.0
# tbb                                      2022.3.0
# tblib                                    3.2.1
# tcmlib                                   1.4.1
# tenacity                                 8.5.0
# tensorboard                              2.19.0
# tensorboard-data-server                  0.7.2
# tensorflow                               2.19.0
# tensorflow-datasets                      4.9.9
# tensorflow_decision_forests              1.12.0
# tensorflow-hub                           0.16.1
# tensorflow-metadata                      1.17.2
# tensorflow-probability                   0.25.0
# tensorflow-text                          2.19.0
# tensorstore                              0.1.78
# termcolor                                3.2.0
# terminado                                0.18.1
# text-unidecode                           1.3
# textblob                                 0.19.0
# tf_keras                                 2.19.0
# tf-slim                                  1.1.0
# thinc                                    8.3.8
# threadpoolctl                            3.6.0
# tifffile                                 2025.10.16
# tiktoken                                 0.12.0
# timm                                     1.0.22
# tinycss2                                 1.4.0
# tokenizers                               0.22.1
# toml                                     0.10.2
# tomlkit                                  0.13.3
# toolz                                    0.12.1
# torch                                    2.8.0+cu126
# torchao                                  0.10.0
# torchaudio                               2.8.0+cu126
# torchdata                                0.11.0
# torchsummary                             1.5.1
# torchtune                                0.6.1
# torchvision                              0.23.0+cu126
# tornado                                  6.5.1
# tqdm                                     4.67.1
# traitlets                                5.7.1
# traittypes                               0.2.3
# transformers                             4.57.1
# treelite                                 4.4.1
# treescope                                0.1.10
# triton                                   3.4.0
# tsfresh                                  0.21.1
# tweepy                                   4.16.0
# typeguard                                4.4.4
# typer                                    0.20.0
# typer-slim                               0.20.0
# types-pytz                               2025.2.0.20251108
# types-setuptools                         80.9.0.20250822
# typing_extensions                        4.15.0
# typing-inspection                        0.4.2
# tzdata                                   2025.2
# tzlocal                                  5.3.1
# uc-micro-py                              1.0.3
# ucxx-cu12                                0.46.0
# umap-learn                               0.5.9.post2
# umf                                      1.0.2
# uri-template                             1.3.0
# uritemplate                              4.2.0
# urllib3                                  2.5.0
# uvicorn                                  0.38.0
# vega-datasets                            0.9.0
# wadllib                                  1.3.6
# wandb                                    0.22.3
# wasabi                                   1.1.3
# watchdog                                 6.0.0
# wcwidth                                  0.2.14
# weasel                                   0.4.2
# webcolors                                25.10.0
# webencodings                             0.5.1
# websocket-client                         1.9.0
# websockets                               15.0.1
# Werkzeug                                 3.1.3
# wheel                                    0.45.1
# widgetsnbextension                       3.6.10
# wordcloud                                1.9.4
# wrapt                                    2.0.1
# wurlitzer                                3.1.1
# xarray                                   2025.10.1
# xarray-einstats                          0.9.1
# xgboost                                  3.1.1
# xlrd                                     2.0.2
# xxhash                                   3.6.0
# xyzservices                              2025.10.0
# yarl                                     1.22.0
# ydf                                      0.13.0
# yellowbrick                              1.5
# yfinance                                 0.2.66
# zict                                     3.0.0
# zipp                                     3.23.0
# zstandard                                0.25.0
